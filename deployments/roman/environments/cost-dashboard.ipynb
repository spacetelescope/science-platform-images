# %% [markdown]
# # Credits Dashboard
#
# This interactive dashboard helps you visualize and export your credits across time periods.
#
# With this tool you can:
#  - Load all your daily aggregated credit data
#  - Filter by date range and credit metric
#  - Export filtered data to a CSV file placed in your home directory
#
# For more information on Accounts and Credit changes see:
#  - https://roman-docs.stsci.edu/data-handbook/roman-research-nexus
#  - https://roman-docs.stsci.edu/data-handbook/roman-research-nexus/benchmarking-examples-and-estimated-costs-on-the-roman-research-nexus

# %%
from IPython.display import Markdown, display
from pathlib import Path

script_path = Path("./costdashboard.py")

try:
    if script_path.exists():
        get_ipython().run_line_magic("run", str(script_path))
    else:
        raise FileNotFoundError(str(script_path))
except Exception:
    display(Markdown(
        "**Please wait until we have collected more metrics from your sessions.**\n\n"
    ))
# Out:
# interactive(children=(Dropdown(description='User:', options=('jmiller',), value='jmiller'), Dropdown(descripti…
# Button(description='Export CSV', style=ButtonStyle())
