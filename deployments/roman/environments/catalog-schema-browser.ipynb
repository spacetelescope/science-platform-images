# %%
from IPython.display import display, HTML

# Specify the URL and dimensions
url = 'https://mastdev.stsci.edu/schema_browser/#/'

# Use HTML wrapper so CSS calc() for vh works and outer notebook does not scroll before iframe
display(HTML(f"""
<style>
  .autofit-iframe {{
    width: 100%;
    height: calc(100vh - 180px);
    min-height: 500px;
    max-height: calc(100vh - 120px);
    border: 0;
  }}
</style>
<iframe class="autofit-iframe" src="{url}"></iframe>
"""))
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="https://mastdev.stsci.edu/schema_browser/#/Roman/Spectra%20(MOCK)%20V3.3/file_metadata"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
