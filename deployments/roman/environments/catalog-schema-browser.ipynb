# %% [markdown]
# # Catalog Schema Browser

# %%
from IPython.display import IFrame

# Specify the URL and dimensions
url = 'https://mastdev.stsci.edu/schema_browser/#/Roman/Spectra%20(MOCK)%20V3.3/file_metadata'
width = '100%'
height = '600px'

# Display the iframe
IFrame(src=url, width=width, height=height)
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="https://mastdev.stsci.edu/schema_browser/#/Roman/Spectra%20(MOCK)%20V3.3/file_metadata"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
