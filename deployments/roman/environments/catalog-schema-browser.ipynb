# %%
import os
from IPython.display import display, HTML

# Specify the URL
url = os.environ.get("CSB_URL", "https://archive.stsci.edu")

# Use HTML wrapper so CSS calc() for vh works and outer notebook does not scroll before iframe
display(HTML(f"""
<style>
  .autofit-iframe {{
    width: 100%;
    height: calc(100vh - 180px);
    min-height: 500px;
    max-height: calc(100vh - 120px);
    border: 0;
  }}
</style>
<iframe class="autofit-iframe" src="{url}"></iframe>
"""))
